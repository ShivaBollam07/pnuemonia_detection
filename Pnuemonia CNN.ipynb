# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %% [markdown]
# Transformations

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2, zoom_range = 0.2,horizontal_flip = True)

# %%
training_set = train_datagen.flow_from_directory(
   'chest_xray/train',
    target_size = (64,64),
    batch_size = 32,
    class_mode ='binary'
)
# Out:
# Found 5216 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
testing_set = test_datagen.flow_from_directory(
    'chest_xray/test',
    target_size = (64,64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size = 3,activation='relu' , input_shape=[64,64,3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size = 3,activation='relu'))

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))  #Number of Neurons = 128

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam' , loss ='binary_crossentropy',metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set,validation_data = testing_set, epochs = 30)
# Out:
# Epoch 1/30
# 163/163 [==============================] - 87s 526ms/step - loss: 0.3915 - accuracy: 0.8267 - val_loss: 0.4250 - val_accuracy: 0.7997
# Epoch 2/30
# 163/163 [==============================] - 81s 498ms/step - loss: 0.2552 - accuracy: 0.9020 - val_loss: 0.3072 - val_accuracy: 0.8670
# Epoch 3/30
# 163/163 [==============================] - 81s 496ms/step - loss: 0.2147 - accuracy: 0.9110 - val_loss: 0.5063 - val_accuracy: 0.8125
# Epoch 4/30
# 163/163 [==============================] - 81s 498ms/step - loss: 0.1964 - accuracy: 0.9227 - val_loss: 0.4368 - val_accuracy: 0.8365
# Epoch 5/30
# 163/163 [==============================] - 81s 497ms/step - loss: 0.1827 - accuracy: 0.9262 - val_loss: 0.2934 - val_accuracy: 0.8862
# Epoch 6/30
# 163/163 [==============================] - 79s 484ms/step - loss: 0.1809 - accuracy: 0.9281 - val_loss: 0.3934 - val_accuracy: 0.8606
# Epoch 7/30
# 163/163 [==============================] - 80s 494ms/step - loss: 0.1717 - accuracy: 0.9293 - val_loss: 0.3067 - val_accuracy: 0.8878
# Epoch 8/30
# 163/163 [==============================] - 82s 501ms/step - loss: 0.1521 - accuracy: 0.9369 - val_loss: 0.2534 - val_accuracy: 0.9103
# Epoch 9/30
# 163/163 [==============================] - 83s 508ms/step - loss: 0.1510 - accuracy: 0.9415 - val_loss: 0.2651 - val_accuracy: 0.9071
# Epoch 10/30
# 163/163 [==============================] - 82s 504ms/step - loss: 0.1481 - accuracy: 0.9436 - val_loss: 0.6300 - val_accuracy: 0.8317
# Epoch 11/30
# 163/163 [==============================] - 91s 556ms/step - loss: 0.1451 - accuracy: 0.9450 - val_loss: 0.2547 - val_accuracy: 0.8878
# Epoch 12/30
# 163/163 [==============================] - 85s 523ms/step - loss: 0.1484 - accuracy: 0.9446 - val_loss: 0.2221 - val_accuracy: 0.8942
# Epoch 13/30
# 163/163 [==============================] - 85s 521ms/step - loss: 0.1396 - accuracy: 0.9461 - val_loss: 0.2503 - val_accuracy: 0.9006
# Epoch 14/30
# 163/163 [==============================] - 77s 472ms/step - loss: 0.1374 - accuracy: 0.9486 - val_loss: 0.2983 - val_accuracy: 0.8974
# Epoch 15/30
# 163/163 [==============================] - 125s 766ms/step - loss: 0.1291 - accuracy: 0.9503 - val_loss: 0.3002 - val_accuracy: 0.8990
# Epoch 16/30
# 163/163 [==============================] - 92s 563ms/step - loss: 0.1298 - accuracy: 0.9511 - val_loss: 0.3472 - val_accuracy: 0.8814
# Epoch 17/30
# 163/163 [==============================] - 133s 819ms/step - loss: 0.1264 - accuracy: 0.9526 - val_loss: 0.4610 - val_accuracy: 0.8526
# Epoch 18/30
# 163/163 [==============================] - 106s 650ms/step - loss: 0.1199 - accuracy: 0.9565 - val_loss: 0.3731 - val_accuracy: 0.8894
# Epoch 19/30
# 163/163 [==============================] - 96s 588ms/step - loss: 0.1200 - accuracy: 0.9572 - val_loss: 0.2786 - val_accuracy: 0.8910
# Epoch 20/30
# 163/163 [==============================] - 131s 802ms/step - loss: 0.1141 - accuracy: 0.9586 - val_loss: 0.3588 - val_accuracy: 0.8926
# Epoch 21/30
# 163/163 [==============================] - 88s 539ms/step - loss: 0.1214 - accuracy: 0.9538 - val_loss: 0.2673 - val_accuracy: 0.9199
# Epoch 22/30
# 163/163 [==============================] - 106s 649ms/step - loss: 0.1096 - accuracy: 0.9588 - val_loss: 0.2676 - val_accuracy: 0.9151
# Epoch 23/30
# 163/163 [==============================] - 83s 509ms/step - loss: 0.0995 - accuracy: 0.9615 - val_loss: 0.3267 - val_accuracy: 0.8974
# Epoch 24/30
# 163/163 [==============================] - 83s 512ms/step - loss: 0.1091 - accuracy: 0.9611 - val_loss: 0.3292 - val_accuracy: 0.8862
# Epoch 25/30
# 163/163 [==============================] - 84s 518ms/step - loss: 0.1024 - accuracy: 0.9611 - val_loss: 0.4129 - val_accuracy: 0.8638
# Epoch 26/30
# 163/163 [==============================] - 82s 501ms/step - loss: 0.1040 - accuracy: 0.9634 - val_loss: 0.4267 - val_accuracy: 0.8638
# Epoch 27/30
# 163/163 [==============================] - 77s 470ms/step - loss: 0.1059 - accuracy: 0.9571 - val_loss: 0.2725 - val_accuracy: 0.9006
# Epoch 28/30
# 163/163 [==============================] - 83s 506ms/step - loss: 0.1123 - accuracy: 0.9561 - val_loss: 0.2672 - val_accuracy: 0.9119
# Epoch 29/30
# 163/163 [==============================] - 87s 533ms/step - loss: 0.0934 - accuracy: 0.9649 - val_loss: 0.2535 - val_accuracy: 0.9119
# Epoch 30/30
# 163/163 [==============================] - 81s 494ms/step - loss: 0.0942 - accuracy: 0.9670 - val_loss: 0.2490 - val_accuracy: 0.9199

# %%
cnn.save('trained_model.h5')

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras.models import load_model

path = './chest_xray/RandomImages/1.jpg'

test_image = image.load_img(path, target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

result = cnn.predict(test_image)



if result[0][0] >= 0.5:
    prediction = 'Pnuemonia Detected'
else:
    prediction = 'Normal'

print("Prediction:", prediction)
# Out:
# 1/1 [==============================] - 1s 797ms/step
# Prediction: Pnuemonia Detected

# %%
# !streamlit run app.py
